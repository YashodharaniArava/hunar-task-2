# %% [markdown]
# # Task : House Price Prediction

# %% [markdown]
# ##  Description:
#  * Create a machine learning model using linear regression and housing dataset. In this project you have to predict house prices using various features given in the dataset.

# %% [markdown]
# ## Requirements:
#  * Basic understanding of pandas and linear regression model.
#  * Jupyter Notebook or any Python environment.

# %% [markdown]
# ## Steps to Follow:
#  1. Import libraries and dataset:
#  * Import necessary libraries like pandas.
#  * Import dataset given to you with task file.
#  2. Data preprocessing:
#  * Remove null values and duplicates from the dataset.
#  * Split the dataset into training and testing data.
#  3. Implement Model:
#   * Apply linear regression model on the training dataset and check its accuracy.
#  4. Model Evaluation:
# * Test the model by using test dataset if model is predicting accurate values then your model is accurate.
#  5. Testing:
# * Test your model by different datasets .

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
data = pd.read_csv("house price data.csv")
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %% [markdown]
# ## Basic Checks

# %%
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
data.tail()
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
data.describe(include =['O'])
# Out:
#                        date                 street     city  statezip country
# count                  4600                   4600     4600      4600    4600
# unique                   70                   4525       44        77       1
# top     2014-06-23 00:00:00  2520 Mulberry Walk NE  Seattle  WA 98103     USA
# freq                    142                      4     1573       148    4600

# %%
data.drop(['date', 'street', 'country', 'statezip'],inplace=True,axis=1)

# %%
data.duplicated().sum()             # To check duplicates
# Out:
# 0

# %%
data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'city'],
#       dtype='object')

# %% [markdown]
# ## Hypothesis
#    * After reading the dataset and understanding the variables.It seems like that target variable(Price)

# %% [markdown]
# ## EDA

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize = (15,15))
plotnumber = 1

for i in data:
    plt.subplot(5, 3, plotnumber)
    sns.histplot(x = data[i])
    plotnumber = plotnumber + 1
plt.tight_layout()

# %% [markdown]
# # Bivariate Analysis

# %%
data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'city'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %%
data.price.value_counts()
# Out:
# 0.0          49
# 300000.0     42
# 400000.0     31
# 440000.0     29
# 450000.0     29
#              ..
# 684680.0      1
# 609900.0      1
# 1635000.0     1
# 1339000.0     1
# 220600.0      1
# Name: price, Length: 1741, dtype: int64

# %%
# Finding Null values

# %%
data.isnull().sum()          # No null Values
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# city             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          4600 non-null   float64
#  1   bedrooms       4600 non-null   float64
#  2   bathrooms      4600 non-null   float64
#  3   sqft_living    4600 non-null   int64
#  4   sqft_lot       4600 non-null   int64
#  5   floors         4600 non-null   float64
#  6   waterfront     4600 non-null   int64
#  7   view           4600 non-null   int64
#  8   condition      4600 non-null   int64
#  9   sqft_above     4600 non-null   int64
#  10  sqft_basement  4600 non-null   int64
#  11  yr_built       4600 non-null   int64
#  12  yr_renovated   4600 non-null   int64
#  13  city           4600 non-null   object
# dtypes: float64(4), int64(9), object(1)
# memory usage: 503.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data.city = le.fit_transform(data.city)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          4600 non-null   float64
#  1   bedrooms       4600 non-null   float64
#  2   bathrooms      4600 non-null   float64
#  3   sqft_living    4600 non-null   int64
#  4   sqft_lot       4600 non-null   int64
#  5   floors         4600 non-null   float64
#  6   waterfront     4600 non-null   int64
#  7   view           4600 non-null   int64
#  8   condition      4600 non-null   int64
#  9   sqft_above     4600 non-null   int64
#  10  sqft_basement  4600 non-null   int64
#  11  yr_built       4600 non-null   int64
#  12  yr_renovated   4600 non-null   int64
#  13  city           4600 non-null   int32
# dtypes: float64(4), int32(1), int64(9)
# memory usage: 485.3 KB

# %% [markdown]
# ## Checking for outliers

# %%
data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'city'],
#       dtype='object')

# %%
data_box=data[['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
       'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
       'yr_built', 'yr_renovated', 'city']]

# %%
plt.figure(figsize=(25,20),facecolor='white')

plotnumber=1

for column in data_box:
    if plotnumber<=19 :
        ax=plt.subplot(4,5,plotnumber)
        sns.boxplot(data[column])
       
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\Arava yashodharani\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Arava yashodharani\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
data.price.unique()
# Out:
# array([ 313000.      , 2384000.      ,  342000.      , ...,
#         416904.166667,  203400.      ,  220600.      ])

# %%
from scipy import stats             #importing stats for scipy library

# %% [markdown]
# ### Bedrooms

# %%
IQR=stats.iqr(data.bedrooms,interpolation='midpoint')        #calculating Inter quantile range
IQR
# Out:
# 1.0

# %%
Q1=data.bedrooms.quantile(0.25)   #defining 25% of data
Q1
# Out:
# 3.0

# %%
Q3=data.bedrooms.quantile(0.75)   #defining 75% of data
Q3
# Out:
# 4.0

# %%
min_limit=Q1-1.5*IQR              #setting minimum limit
min_limit
# Out:
# 1.5

# %%
max_limit=Q3+1.5*IQR              #setting maximum limit
max_limit
# Out:
# 5.5

# %%
data.loc[data['bedrooms']<min_limit]         #checking values which are less than minimum limit
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 260    250000.0       1.0       1.00         1100      4373     1.0
# 477    235000.0       1.0       1.00          810      2451     1.0
# 784    350000.0       1.0       1.00          700      5100     1.0
# 831    540000.0       1.0       1.00         1140      6700     1.5
# 883    285000.0       1.0       1.50          810      3211     2.0
# 969    458000.0       1.0       2.25         2140     10350     1.0
# 1018   194000.0       1.0       1.00          820      1060     1.0
# 1051   420850.0       1.0       1.00          960     40946     1.0
# 1140   275000.0       1.0       0.75         1170     14149     1.0
# 1216   353000.0       1.0       1.00          550      1279     2.0
# 1219    80000.0       1.0       0.75          430      5050     1.0
# 1238   527550.0       1.0       0.75          820     59677     1.0
# 1663   250000.0       1.0       1.00          750      4000     1.0
# ...

# %%
data.loc[data['bedrooms']>max_limit]         #checking values which are less than maximum limit
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 92    8.230000e+05       6.0       1.75         2920      5000     2.5
# 122   2.280000e+06       7.0       8.00        13540    307752     3.0
# 170   4.750000e+05       6.0       3.00         3470    117612     1.5
# 241   5.999990e+05       9.0       4.50         3830      6988     2.5
# 252   3.200000e+06       7.0       4.50         6210      8856     2.5
# ...            ...       ...        ...          ...       ...     ...
# 4301  8.800000e+05       6.0       2.50         2640      3680     2.0
# 4341  3.750000e+05       6.0       2.25         3206      5793     2.0
# 4357  0.000000e+00       6.0       2.75         3200      9200     1.0
# 4509  0.000000e+00       6.0       3.00         3020     13783     2.0
# 4572  1.288333e+06       6.0       4.50         3830      4800     3.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
data.loc[data['bedrooms'] < min_limit, 'bedrooms'] = np.median(data['bedrooms'])

# %%
data.loc[data['bedrooms'] > max_limit, 'bedrooms'] = np.median(data['bedrooms'])

# %%
data.bedrooms=np.sqrt(data.bedrooms)

# %% [markdown]
# ### bathrooms

# %%
IQR=stats.iqr(data.bathrooms,interpolation='midpoint')        #calculating Inter quantile range
IQR
# Out:
# 0.75

# %%
Q1 = data.bathrooms.quantile(0.25)
Q1
# Out:
# 1.75

# %%
Q3 = data. bathrooms.quantile(0.75)
Q3
# Out:
# 2.5

# %%
min_limit = Q1-1.5*IQR
min_limit
# Out:
# 0.625

# %%
max_limit = Q3+1.5*IQR
max_limit
# Out:
# 3.625

# %%
data.loc[data['bathrooms']< min_limit]
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2365  1095000.0  1.732051        0.0         3064      4764     3.5
# 3209  1295648.0  1.732051        0.0         4810     28008     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 2365           0     2          3        3064              0      1990
# 3209           0     0          3        4810              0      1990
#
#       yr_renovated  city
# 2365          2009    35
# 3209          2009    31

# %%
data.loc[data['bathrooms']>max_limit]
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 122   2.280000e+06  1.732051       8.00        13540    307752     3.0
# 143   8.900000e+05  2.000000       4.25         4420      5750     2.0
# 217   1.870000e+06  2.236068       4.00         4510     15175     2.0
# 223   3.900000e+05  2.236068       3.75         2890      5000     1.0
# 227   1.800000e+06  2.236068       5.00         4490     10279     2.0
# ...            ...       ...        ...          ...       ...     ...
# 4523  0.000000e+00  1.732051       4.50         5230     17826     2.0
# 4528  0.000000e+00  2.000000       5.00         4550     18641     1.0
# 4558  0.000000e+00  2.000000       4.25         3500      8750     1.0
# 4572  1.288333e+06  1.732051       4.50         3830      4800     3.0
# 4575  0.000000e+00  2.236068       6.25         8020     21738     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
data.loc[data['bathrooms'] < min_limit, 'bathrooms'] = np.median(data['bathrooms'])

# %%
data.loc[data['bathrooms'] > max_limit, 'bathrooms'] = np.median(data['bathrooms'])

# %%
data.bathrooms=np.sqrt(data.bathrooms)

# %% [markdown]
# ###  sqft_living

# %%
IQR=stats.iqr(data.sqft_living,interpolation='midpoint')        #calculating Inter quantile range
IQR
# Out:
# 1160.0

# %%
Q1 = data.sqft_living.quantile(0.25)
Q1
# Out:
# 1460.0

# %%
Q3 = data.sqft_living.quantile(0.75)
Q3
# Out:
# 2620.0

# %%
min_limit = Q1-1.5*IQR
min_limit
# Out:
# -280.0

# %%
max_limit = Q3+1.5*IQR
max_limit
# Out:
# 4360.0

# %%
data.loc[data['sqft_living']< min_limit]
# Out:
# Empty DataFrame
# Columns: [price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, city]
# Index: []

# %%
data.loc[data['sqft_living'] >  max_limit]
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 122   2280000.0  1.732051   1.500000        13540    307752     3.0
# 143    890000.0  2.000000   1.500000         4420      5750     2.0
# 148    890000.0  2.236068   1.870829         4490      6000     2.0
# 217   1870000.0  2.236068   1.500000         4510     15175     2.0
# 227   1800000.0  2.236068   1.500000         4490     10279     2.0
# ...         ...       ...        ...          ...       ...     ...
# 4400   692000.0  2.000000   1.802776         5010     34460     2.0
# 4432   452500.0  2.236068   1.870829         5960     13703     2.0
# 4523        0.0  1.732051   1.500000         5230     17826     2.0
# 4528        0.0  2.000000   1.500000         4550     18641     1.0
# 4575        0.0  2.236068   1.500000         8020     21738     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 122            0     4          3        9410           4130      1999
# ...

# %%
data.loc[data['sqft_living'] > max_limit, 'sqft_living'] = np.median(data['sqft_living'])

# %%
data.sqft_living=np.sqrt(data.sqft_living)

# %% [markdown]
# ###  sqft_lot

# %%
IQR=stats.iqr(data.sqft_lot,interpolation='midpoint')        #calculating Inter quantile range
IQR
# Out:
# 6002.0

# %%
Q1 = data.sqft_lot.quantile(0.25)
Q1
# Out:
# 5000.75

# %%
Q3 = data.sqft_lot.quantile(0.75)
Q3
# Out:
# 11001.25

# %%
min_limit = Q1-1.5*IQR
min_limit
# Out:
# -4002.25

# %%
max_limit=Q3+1.5*IQR
max_limit
# Out:
# 20004.25

# %%
data.loc[data['sqft_lot']< min_limit]
# Out:
# Empty DataFrame
# Columns: [price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, city]
# Index: []

# %%
data.loc[data['sqft_lot']< max_limit]
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05  1.732051   1.224745    36.606010      7912     1.5
# 1     2.384000e+06  2.236068   1.581139    60.415230      9050     2.0
# 2     3.420000e+05  1.732051   1.414214    43.931765     11947     1.0
# 3     4.200000e+05  1.732051   1.500000    44.721360      8030     1.0
# 4     5.500000e+05  2.000000   1.581139    44.045431     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05  1.732051   1.322876    38.858718      6360     1.0
# 4596  5.343333e+05  1.732051   1.581139    38.209946      7573     2.0
# 4597  4.169042e+05  1.732051   1.581139    54.863467      7014     2.0
# 4598  2.034000e+05  2.000000   1.414214    45.716518      6630     1.0
# 4599  2.206000e+05  1.732051   1.581139    38.600518      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
data.loc[data['sqft_lot'] > max_limit, 'sqft_lot'] = np.median(data['sqft_lot'])

# %%
data.sqft_lot=np.sqrt(data.sqft_lot)

# %% [markdown]
# ### sqft_above

# %%
IQR=stats.iqr(data.sqft_above,interpolation='midpoint')        #calculating Inter quantile range
IQR
# Out:
# 1110.0

# %%
Q1=data.sqft_above.quantile(0.25)
Q1
# Out:
# 1190.0

# %%
Q3=data.sqft_above.quantile(0.75)
Q3
# Out:
# 2300.0

# %%
min_limit = Q1-1.5*IQR
min_limit
# Out:
# -475.0

# %%
max_limit=Q3+1.5*IQR
max_limit
# Out:
# 3965.0

# %%
data.loc[data['sqft_above']< min_limit]
# Out:
# Empty DataFrame
# Columns: [price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, city]
# Index: []

# %%
data.loc[data['sqft_above']< max_limit]
# Out:
#              price  bedrooms  bathrooms  sqft_living    sqft_lot  floors  \
# 0     3.130000e+05  1.732051   1.224745    36.606010   88.949424     1.5
# 1     2.384000e+06  2.236068   1.581139    60.415230   95.131488     2.0
# 2     3.420000e+05  1.732051   1.414214    43.931765  109.302333     1.0
# 3     4.200000e+05  1.732051   1.500000    44.721360   89.610267     1.0
# 4     5.500000e+05  2.000000   1.581139    44.045431  102.469508     1.0
# ...            ...       ...        ...          ...         ...     ...
# 4595  3.081667e+05  1.732051   1.322876    38.858718   79.749608     1.0
# 4596  5.343333e+05  1.732051   1.581139    38.209946   87.022985     2.0
# 4597  4.169042e+05  1.732051   1.581139    54.863467   83.749627     2.0
# 4598  2.034000e+05  2.000000   1.414214    45.716518   81.424812     1.0
# 4599  2.206000e+05  1.732051   1.581139    38.600518   90.011110     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
data.loc[data['sqft_above'] > max_limit, 'sqft_above'] = np.median(data['sqft_above'])

# %%
data.sqft_above=np.sqrt(data.sqft_above)

# %% [markdown]
# ### sqft_basement

# %%
IQR=stats.iqr(data.sqft_basement,interpolation='midpoint')        #calculating Inter quantile range
IQR
# Out:
# 610.0

# %%
Q1=data.sqft_basement.quantile(0.25)
Q1
# Out:
# 0.0

# %%
Q3=data.sqft_basement.quantile(0.75)
Q3
# Out:
# 610.0

# %%
min_limit = Q1-1.5*IQR
min_limit
# Out:
# -915.0

# %%
max_limit=Q3+1.5*IQR
max_limit
# Out:
# 1525.0

# %%
data.loc[data['sqft_basement']< min_limit]
# Out:
# Empty DataFrame
# Columns: [price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, city]
# Index: []

# %%
data.loc[data['sqft_basement']> max_limit]
# Out:
#           price  bedrooms  bathrooms  sqft_living    sqft_lot  floors  \
# 122   2280000.0  1.732051   1.500000    44.497191   87.652724     3.0
# 223    390000.0  2.236068   1.500000    53.758720   70.710678     1.0
# 414   1370000.0  2.000000   1.658312    60.991803   97.211110     1.0
# 452   1702500.0  2.236068   1.500000    44.497191   87.652724     2.0
# 471   1225000.0  2.000000   1.500000    44.497191   87.652724     1.0
# ...         ...       ...        ...          ...         ...     ...
# 4385        0.0  2.000000   1.500000    44.497191  104.990476     2.0
# 4398   195000.0  2.236068   1.500000    44.497191  103.223059     2.5
# 4416   316850.0  2.000000   1.732051    63.718129   87.652724     1.0
# 4524   288500.0  2.236068   1.581139    58.223707   98.792712     1.0
# 4528        0.0  2.000000   1.500000    44.497191  136.532048     1.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
data.loc[data['sqft_basement'] > max_limit, 'sqft_basement'] = np.median(data['sqft_basement'])

# %%
data.sqft_basement=np.sqrt(data.sqft_basement)

# %% [markdown]
# ## Scaling the data

# %% [markdown]
# ## Feature Selection

# %%
plt.figure(figsize=(30,30))#canvas size
sns.heatmap(data.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":15})#plotting heat map to check correlation
# Out:
# <AxesSubplot:>

# %%
data.describe()
# Out:
#               price     bedrooms    bathrooms  sqft_living     sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000  4600.000000  4600.000000
# mean   5.519630e+05     1.820801     1.427958    44.433677    83.873800
# std    5.638347e+05     0.218984     0.243441     8.575991    21.242777
# min    0.000000e+00     1.414214     0.866025    19.235384    25.258662
# 25%    3.228750e+05     1.732051     1.322876    38.209946    70.715981
# 50%    4.609435e+05     1.732051     1.500000    44.497191    87.652724
# 75%    6.549625e+05     2.000000     1.581139    50.398413    95.393920
# max    2.659000e+07     2.236068     1.870829    66.030296   141.424892
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739    40.996725
# std       0.538288     0.084404     0.778405     0.677230     8.355253
# ...

# %% [markdown]
# ## Model Creation

# %%
x=data.drop('price',axis=1)
y=data.price

# %%
x
# Out:
#       bedrooms  bathrooms  sqft_living    sqft_lot  floors  waterfront  view  \
# 0     1.732051   1.224745    36.606010   88.949424     1.5           0     0
# 1     2.236068   1.581139    60.415230   95.131488     2.0           0     4
# 2     1.732051   1.414214    43.931765  109.302333     1.0           0     0
# 3     1.732051   1.500000    44.721360   89.610267     1.0           0     0
# 4     2.000000   1.581139    44.045431  102.469508     1.0           0     0
# ...        ...        ...          ...         ...     ...         ...   ...
# 4595  1.732051   1.322876    38.858718   79.749608     1.0           0     0
# 4596  1.732051   1.581139    38.209946   87.022985     2.0           0     0
# 4597  1.732051   1.581139    54.863467   83.749627     2.0           0     0
# 4598  2.000000   1.414214    45.716518   81.424812     1.0           0     0
# 4599  1.732051   1.581139    38.600518   90.011110     2.0           0     0
#
# ...

# %%
y
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(x)
scaled_data
# Out:
# array([[-0.40532792, -0.83484527, -0.91284115, ..., -0.53101376,
#          1.22167046,  0.8618055 ],
#        [ 1.89654289,  0.62929979,  1.86372524, ..., -1.67469295,
#         -0.82569345,  0.77834292],
#        [-0.40532792, -0.05646606, -0.05853155, ..., -0.1609999 ,
#         -0.82569345, -0.64052081],
#        ...,
#        [-0.40532792,  0.62929979,  1.21629375, ...,  1.2854179 ,
#         -0.82569345,  0.5279552 ],
#        [ 0.81840901, -0.05646606,  0.14960143, ...,  0.10810108,
#         -0.82569345,  0.77834292],
#        [-0.40532792,  0.62929979, -0.68024709, ...,  0.64630305,
#         -0.82569345, -1.39168397]])

# %%
from sklearn.model_selection import train_test_split                    #importing train_test_split
x_train,x_test,y_train,y_test=train_test_split(scaled_data,y,test_size=0.25,random_state=42)

# %%
x_train
# Out:
# array([[-0.40532792, -0.83484527, -0.15229744, ..., -0.26191277,
#          1.22473384,  1.19565579],
#        [-1.856906  , -1.75814682, -1.36708364, ..., -0.7328395 ,
#         -0.82569345,  0.77834292],
#        [ 0.81840901, -0.83484527, -0.07182134, ..., -0.39646326,
#          1.20533239, -0.9743711 ],
#        ...,
#        [-0.40532792, -1.75814682, -1.22705015, ..., -1.30467909,
#          1.17367739,  0.8618055 ],
#        [-1.856906  , -1.75814682, -1.6638336 , ..., -2.38108303,
#          1.22167046,  0.77834292],
#        [-1.856906  , -1.75814682, -0.68024709, ..., -1.40559196,
#         -0.82569345,  0.77834292]])

# %%
x_test
# Out:
# array([[-0.40532792,  0.62929979, -0.72579451, ...,  1.21814265,
#         -0.82569345,  0.77834292],
#        [ 1.89654289,  0.29596356,  0.03354878, ...,  0.51175256,
#         -0.82569345,  0.69488035],
#        [-0.40532792,  1.53983273,  1.14146044, ...,  0.24265158,
#          1.21656481,  0.77834292],
#        ...,
#        [-0.40532792, -1.75814682, -1.0918084 , ..., -0.66556425,
#          1.21554368, -1.89245941],
#        [-0.40532792,  0.62929979,  0.84411855, ...,  0.57902781,
#         -0.82569345, -0.64052081],
#        [ 0.81840901,  0.62929979,  0.45945689, ...,  1.01631691,
#         -0.82569345,  0.5279552 ]])

# %%
y_train
# Out:
# 2095    288350.000000
# 1173    319950.000000
# 1954    210000.000000
# 256     515000.000000
# 3341    245700.000000
#             ...
# 4426    282508.888889
# 466     875000.000000
# 3092    290000.000000
# 3772    600000.000000
# 860     475000.000000
# Name: price, Length: 3450, dtype: float64

# %%
y_test
# Out:
# 3683     544000.0
# 4411          0.0
# 2584    1712500.0
# 69       365000.0
# 1844     275000.0
#           ...
# 2772    3000000.0
# 1912     355000.0
# 1260     607000.0
# 801      425000.0
# 2698     465950.0
# Name: price, Length: 1150, dtype: float64

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3450, 13)
# (1150, 13)
# (3450,)
# (1150,)

# %%
# Checking for imbalanced data
data.price.value_counts()
# Out:
# 0.0          49
# 300000.0     42
# 400000.0     31
# 440000.0     29
# 450000.0     29
#              ..
# 684680.0      1
# 609900.0      1
# 1635000.0     1
# 1339000.0     1
# 220600.0      1
# Name: price, Length: 1741, dtype: int64

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = LR.predict(x_test)
y_predict
# Out:
# array([ 403913.72859572,  470919.16765591, 1205964.61685084, ...,
#         286870.34748196,  590441.51122202,  595630.73670877])

# %%
y_pre_train = LR.predict(x_train)
y_pre_train
# Out:
# array([413697.85017416, 488420.17683585, 424156.845788  , ...,
#        346377.8948064 , 358846.17684218, 320487.02148968])

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
# test Score
r2score = r2_score(y_test,y_predict)
r2score
# Out:
# 0.031641893018289236

# %%
r2score=r2_score(y_train,y_pre_train)
r2score
# Out:
# 0.3447318514979485

# %%
adjusted_r2=1-(1-0.031)*(1150-1)/(1150-13-1)
adjusted_r2
# Out:
# 0.019911091549295934

# %%
print(mean_squared_error(y_test,y_predict))
print(math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 815663366919.6295
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7784\1804698431.py in <module>
#       1 print(mean_squared_error(y_test,y_predict))
# ----> 2 print(math.sqrt(mean_squared_error(y_test,y_predict)))
#
# NameError: name 'math' is not defined

# %%
print(mean_absolute_error(y_test,y_predict))
